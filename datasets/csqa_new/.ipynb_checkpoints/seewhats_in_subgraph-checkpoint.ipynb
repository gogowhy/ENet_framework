# %%
import torch

# %%
torch.load('csqa_train_subgraph')
# Out:
# [[[["PersonX pays PersonY's medical bills",
#     'xNeed',
#     'to send a check or digitally online send money to cover the bills.'],
#    0.13986904558770089],
#   [['PersonX visits one',
#     'xNeed',
#     "drive to the place where they're doing the visiting"],
#    0.0986387855766426],
#   [["PersonX does PersonX's damnedest",
#     'xNeed',
#     'to want to do it the best they can'],
#    0.08394471237224971],
#   [['PersonX gives PersonY the number',
#     'oWant',
#     "to tell PersonX that they'll talk to them later"],
#    0.07845324355371507],
#   [['PersonX gives PersonY the number',
#     'xWant',
#     "to tell PersonY that they'll talk to them later"],
#    0.07845324355371507]],
#  [[["PersonX pays PersonY's medical bills",
#     'xNeed',
#     'to send a check or digitally online send money to cover the bills.'],
#    0.26601793705829224],
#   [['PersonX gets the stain out',
#     'xNeed',
#     'to have the right tools to get stain out'],
# ...
